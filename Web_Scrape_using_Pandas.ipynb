# %%
pip install pandas

# %%
import pandas as pd

# %%
url="https://en.wikipedia.org/wiki/Economy_of_Pakistan"
tables = pd.read_html(url)

# %%
df = tables[6]

# %%
df
# Out:
#     Year  GDP (Billion US $ PPP)  GDP per capita (US$ PPP)  \
# 0   1980                    79.0                     950.0
# 1   1981                    91.8                    1072.8
# 2   1982                   104.9                    1190.0
# 3   1983                   116.4                    1283.6
# 4   1984                   125.4                    1345.3
# 5   1985                   140.6                    1468.4
# 6   1986                   152.5                    1551.3
# 7   1987                   165.4                    1638.5
# 8   1988                   182.2                    1759.4
# 9   1989                   198.5                    1868.3
# 10  1990                   215.4                    1970.1
# 11  1991                   234.1                    2094.8
# 12  1992                   257.5                    2211.1
# 13  1993                   269.2                    2252.4
# 14  1994                   286.9                    2341.1
# ...

# %%
df.to_csv('wiki.csv', index=False)
